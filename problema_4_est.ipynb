# %%
import pandas as pd
import numpy as np

lista_n_ordenada = [
    19, 23, 33, 19, 11, 8, 16, 79, 23, 22, 2, 4, 13, 0, 32, 6, 9, 5, 22, 42, 4, 52, 45, 79,
    11, 32, 31, 4, 1, 96, 67, 5, 3, 22, 67, 14, 25, 1, 4, 23, 19, 15, 1, 24, 0, 56, 16, 124,
    18, 22, 17, 5, 44, 3, 30, 6, 31, 2, 5, 22, 2, 7, 13, 7
]

lista_ordenada = sorted(lista_n_ordenada)

df = pd.DataFrame(lista_ordenada, columns=['Valores'])

print(df.head())
# Out:
#    Valores
# 0        0
# 1        0
# 2        1
# 3        1
# 4        1

# %%
media = df['Valores'].mean()

mediana = df['Valores'].median()

variancia = df['Valores'].var()

desvio_padrão = df['Valores'].std()

min = df['Valores'].min()

max = df['Valores'].max()

quartis = df['Valores'].quantile([0.25,0.5,0.75])

print(f"Media = {media:.2f} minutos")
print(f"Mediana = {mediana:.2f} minutos")
print(f"Variancia = {variancia:.2f} minutos\u00B2")
print(f"Desvio Padrão = {desvio_padrão:.2f} minutos")
print(f"Min = {min:.2f} minutos")
print(f"Max = {max:.2f} minutos")
print(f"Quartis = {quartis}")
# Out:
# Media = 22.86 minutos
# Mediana = 16.50 minutos
# Variancia = 620.03 minutos²
# Desvio Padrão = 24.90 minutos
# Min = 0.00 minutos
# Max = 124.00 minutos
# Quartis = 0.25     5.00
# 0.50    16.50
# 0.75    30.25
# Name: Valores, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import norm

media, desvio_padrao = norm.fit(df['Valores'])

# Gerar valores x para a curva normal
x = np.linspace(df['Valores'].min(), df['Valores'].max(), 100)
y = norm.pdf(x, media, desvio_padrao)
# Configurando estilo de exibição do Seaborn
sns.set(style="whitegrid")

#Histrograma sem linha de densidade e com frêquencia
plt.figure(figsize=(5, 3))
sns.histplot(df['Valores'], kde=False)
plt.title('Histograma dos Valores')
plt.xlabel('Valores')
plt.ylabel('Frequência')
plt.show()

# Histograma com linha de densidade e linha vertical para a média
plt.figure(figsize=(5, 3))
sns.histplot(df['Valores'], kde=False, color='gray', stat='density')
plt.plot(x, y, 'r-', lw=2, label='Curva Normal')
plt.axvline(media, color='blue', linestyle='dashed', linewidth=1, label='Média')
plt.title('Histograma Densidade com Curva Normal')
plt.xlabel('Tempo (s)')
plt.ylabel('Densidade')
plt.legend()
plt.show()

# Boxplot
plt.figure(figsize=(3, 7))
sns.boxplot(y=df['Valores'])
plt.title('Boxplot dos tempos')
plt.ylabel('Tempo (s)')
plt.show()
# Out:
# c:\Users\Pedro\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\Pedro\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
p = 1/media

print(f"A distribuição estimada Nn (Seguindo uma distribuição Binomial) para todo k = 1,2,3... é: Nt ~ (n,{p:.2})")
print()
print(f"A distribuição Tk (Seguindo uma distribuição Binomial Negativa) pode ser estimada para todo k = 1,2,3... por: Tk ~(k,{p:.2})")
# Out:
# A distribuição estimada Nn (Seguindo uma distribuição Binomial) para todo k = 1,2,3... é: Nt ~ (n,0.044)
#
# A distribuição Tk (Seguindo uma distribuição Binomial Negativa) pode ser estimada para todo k = 1,2,3... por: Tk ~(k,0.044)

# %%
import math
from scipy.stats import nbinom, binom


# (a) Intensidade do processo de alterações de conteúdo no site
lambda_value = 1 / p
print(f"Intensidade do processo: λ = {lambda_value:.2f} ")

# (b) Tempo médio entre alterações sucessivas de conteúdo no site
mean_time_between_changes = p
print(f"Tempo médio entre alterações: {mean_time_between_changes:.2f}")

# (c) Probabilidade de duas ou mais mudanças em um dia
k = 2  # número mínimo de mudanças desejadas
prob_two_or_more_changes = 1 - nbinom.cdf(k-1, k, p)
print(f"Probabilidade de duas ou mais mudanças em um dia: {prob_two_or_more_changes*100:.2f}%")

# (d) Probabilidade de não haver alterações no conteúdo em cinco dias
n_days = 5
prob_no_changes_5_days = binom.pmf(0, n_days, p)
print(f"Probabilidade de não haver alterações em cinco dias: {prob_no_changes_5_days*100:.2f}%")

# (e) Probabilidade de duas ou menos mudanças em cinco dias
prob_two_or_less_changes_5_days = binom.cdf(2, n_days, p)
print(f"Probabilidade de duas ou menos mudanças em cinco dias: {prob_two_or_less_changes_5_days*100:.2f}%")
# Out:
# Intensidade do processo: λ = 22.86
# Tempo médio entre alterações: 0.04
# Probabilidade de duas ou mais mudanças em um dia: 99.44%
# Probabilidade de não haver alterações em cinco dias: 79.96%
# Probabilidade de duas ou menos mudanças em cinco dias: 99.92%
